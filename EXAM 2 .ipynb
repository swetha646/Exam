# %% [markdown]
# 1, a
# 2, b
# 3, b
# 4, c
# 5, c
# 6, b
# 7, c
# 8, d
# 9, a
# 10, a
# 11, b
# 12, d
# 13, c
# 14, c
# 15, b
# 16, b
# 17, c
# 18, b
# 19, a
# 20, b
# 21, c
# 22, c
# 23, b
# 24, a
# 25, b

# %%
#LOGICAL PROBLEM
n = 5
for i in range(n):
    for j in range(n):
        if i == 0 or i == n-1 or j ==0 or j == n-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# * * * * *
# *       *
# *       *
# *       *
# * * * * *

# %%
#MACHINE TEST

# %% [markdown]
# BUSINESS REQUIREMENT ANALYSIS - EDA

# %% [raw]
# DATA CLEANING AND UNDERSTANDING

# %%
#PART A
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\USER\Downloads\DA_Month2_EDA_Machine_Test_Dataset.csv")

# %%
df
# Out:
#       Order_ID  Order_Date Region         Category      Product  \
# 0     ORD10001  2025-04-10   West  Office Supplies  File Folder
# 1     ORD10002  2025-08-24  North        Furniture        Table
# 2     ORD10003  2025-12-30   East  Office Supplies      Pen Set
# 3     ORD10004  2025-09-22  South      Electronics     Keyboard
# 4     ORD10005  2025-12-26   West         Clothing        Shoes
# ...        ...         ...    ...              ...          ...
# 1210  ORD10088  2025-11-05  North        Furniture         Desk
# 1211  ORD10942  2025-08-24   West        Furniture        Table
# 1212  ORD10191  2025-05-09  South         Clothing      T-Shirt
# 1213  ORD10859  2025-01-19   East  Office Supplies     Notebook
# 1214  ORD11137  2025-11-25   West        Furniture        Table
#
#      Customer_Segment  Quantity  Unit_Price  Discount    Sales Payment_Method
# 0         Home Office         8       27.62      0.20   176.76    Net Banking
# ...

# %%
df.shape
# Out:
# (1215, 11)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Region', 'Category', 'Product',
#        'Customer_Segment', 'Quantity', 'Unit_Price', 'Discount', 'Sales',
#        'Payment_Method'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order_ID             object
# Order_Date           object
# Region               object
# Category             object
# Product              object
# Customer_Segment     object
# Quantity              int64
# Unit_Price          float64
# Discount            float64
# Sales               float64
# Payment_Method       object
# dtype: object

# %%
df.head()
# Out:
#    Order_ID  Order_Date Region         Category      Product Customer_Segment  \
# 0  ORD10001  2025-04-10   West  Office Supplies  File Folder      Home Office
# 1  ORD10002  2025-08-24  North        Furniture        Table         Consumer
# 2  ORD10003  2025-12-30   East  Office Supplies      Pen Set         Consumer
# 3  ORD10004  2025-09-22  South      Electronics     Keyboard         Consumer
# 4  ORD10005  2025-12-26   West         Clothing        Shoes        Corporate
#
#    Quantity  Unit_Price  Discount    Sales Payment_Method
# 0         8       27.62      0.20   176.76    Net Banking
# 1         6      595.56      0.20  2858.69           Cash
# 2        10       38.75      0.10   348.77           Cash
# 3         7      237.81      0.05  1581.42            UPI
# 4         7      126.45      0.05   840.91            UPI

# %%
df.isnull().sum()
# Out:
# Order_ID             0
# Order_Date           0
# Region              10
# Category             0
# Product              0
# Customer_Segment    10
# Quantity             0
# Unit_Price           0
# Discount             0
# Sales                0
# Payment_Method      15
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %%
df['Region'].unique()
# Out:
# array(['West', 'North', 'East', 'South', nan, 'south', 'West ', ' SOUTH'],
#       dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Region
# South     321
# East      296
# West      292
# North     284
#  SOUTH      5
# West        4
# south       3
# Name: count, dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Electronics', 'Clothing'],
#       dtype=object)

# %%
df['Category'].value_counts()
# Out:
# Category
# Electronics        340
# Furniture          324
# Office Supplies    284
# Clothing           267
# Name: count, dtype: int64

# %%
df['Product'].unique()
# Out:
# array(['File Folder', 'Table', 'Pen Set', 'Keyboard', 'Shoes', 'Jeans',
#        'Bookshelf', 'Notebook', 'Printer Paper', 'T-Shirt', 'Headphones',
#        'Monitor', 'Jacket', 'Laptop', 'Chair', 'Desk'], dtype=object)

# %%
df['Product'].value_counts()
# Out:
# Product
# Monitor          93
# Laptop           91
# Chair            89
# Table            83
# Notebook         81
# Keyboard         80
# Bookshelf        78
# Headphones       76
# Desk             74
# Jacket           71
# File Folder      70
# Pen Set          68
# Shoes            68
# Printer Paper    65
# Jeans            64
# T-Shirt          64
# Name: count, dtype: int64

# %%
df['Customer_Segment'].unique()
# Out:
# array(['Home Office', 'Consumer', 'Corporate', nan], dtype=object)

# %%
df['Customer_Segment'].value_counts()
# Out:
# Customer_Segment
# Consumer       411
# Corporate      398
# Home Office    396
# Name: count, dtype: int64

# %%
df['Payment_Method'].unique()
# Out:
# array(['Net Banking', 'Cash', 'UPI', 'Credit Card', 'Debit Card', nan],
#       dtype=object)

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# UPI            255
# Debit Card     247
# Net Banking    240
# Credit Card    231
# Cash           227
# Name: count, dtype: int64

# %%
df['Region']= df['Region'].fillna(df['Region'].mode()[0])

# %%
df['Customer_Segment']= df['Customer_Segment'].fillna(df['Customer_Segment'].mode()[0])

# %%
df['Payment_Method']= df['Payment_Method'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Region              0
# Category            0
# Product             0
# Customer_Segment    0
# Quantity            0
# Unit_Price          0
# Discount            0
# Sales               0
# Payment_Method      0
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df.dtypes
# Out:
# Order_ID                    object
# Order_Date          datetime64[ns]
# Region                      object
# Category                    object
# Product                     object
# Customer_Segment            object
# Quantity                     int64
# Unit_Price                 float64
# Discount                   float64
# Sales                      float64
# Payment_Method              object
# dtype: object

# %%
df['Region']=df['Region'].str.strip()

# %%
df['Region']=df['Region'].str.replace(" SOUTH","South")

# %%
df['Region']=df['Region'].str.replace("south","South")

# %%
df['Region'].value_counts()
# Out:
# Region
# South    333
# West     294
# East     293
# North    280
# Name: count, dtype: int64

# %%
sns.boxplot(x=df['Sales'])
plt.title("box plot of sales")
plt.show()

# %%
df.shape
# Out:
# (1200, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1200 non-null   object
#  1   Order_Date        1200 non-null   datetime64[ns]
#  2   Region            1200 non-null   object
#  3   Category          1200 non-null   object
#  4   Product           1200 non-null   object
#  5   Customer_Segment  1200 non-null   object
#  6   Quantity          1200 non-null   int64
#  7   Unit_Price        1200 non-null   float64
#  8   Discount          1200 non-null   float64
#  9   Sales             1200 non-null   float64
#  10  Payment_Method    1200 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 112.5+ KB

# %%
#PART B
#1
df['Sales'].sum()
# Out:
# np.float64(1831811.51)

# %%
#2
df['Sales'].mean()
# Out:
# np.float64(1526.5095916666667)

# %%
#3 and 4
Cat = df.groupby('Category')['Sales'].sum().sort_values(ascending = False)
Cat
# Out:
# Category
# Electronics        977969.39
# Furniture          543227.84
# Clothing           204058.41
# Office Supplies    106555.87
# Name: Sales, dtype: float64

# %%
Reg = df.groupby('Region')['Sales'].sum().reset_index()
sns.barplot(data=Reg,x='Region',y='Sales')
plt.title("Sales by region")
plt.xlabel("Region")
plt.ylabel("Total sales")
plt.show()

# %%
sns.histplot(df['Quantity'],kde=True)
plt.title('Distribution of Quantity')
plt.show()

# %%
sns.histplot(df['Unit_Price'],kde=True)
plt.title('Distribution of Price')
plt.show()

# %%
sns.boxplot(df['Discount'])
plt.title('Distribution of Discount')
plt.show()

# %%
sns.boxplot(df['Sales'])
plt.title('Distribution of Sales')
plt.show()

# %%
sns.scatterplot(data=df,x='Unit_Price',y='Sales')
plt.title('price vs sales')
plt.xlabel('unit price')
plt.ylabel('sales')
plt.show()

# %%
plt.scatter(df['Discount'],df['Sales'])
plt.title('Discount vs sales')
plt.xlabel('Discount')
plt.ylabel('sales')
plt.show()

# %%
sns.heatmap(df[['Quantity','Unit_Price','Discount','Sales']].corr(),annot=True,cmap='coolwarm')
plt.title('relation between numerical variables')
plt.show()

# %%
seg = df.groupby('Customer_Segment')['Sales'].sum().reset_index()
sns.barplot(data=seg,x='Customer_Segment',y='Sales')
plt.title("customer segment and sales")
plt.show()

# %%
category_sales=df.groupby("Category")["Sales"].sum()
category_sales.plot(kind="bar")
plt.xlabel("Category")
plt.ylabel("Total_Sales")
plt.title("Total Sales by Category")
plt.show()

# %%
seg = df.groupby('Region')['Sales'].sum().reset_index()
sns.barplot(data=seg,x='Region',y='Sales')
plt.title("Region and sales")
plt.xticks(rotation=45)
plt.show()

# %%
category_sales=df.groupby("Product")["Sales"].sum()
category_sales.plot(kind="bar")
plt.xlabel("product")
plt.ylabel("Total_Sales")
plt.title("Total Sales by product")
plt.show()

# %%
sns.scatterplot(data=df, x='Discount', y='Sales')
plt.title('Discount vs Sales')
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.show()

# %%
sns.lineplot(data=df, x='Order_Date', y='Sales')
plt.title('Sales Trend Over Time')
plt.xlabel('Order Date')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #part c
# 1, electronics - category
#    keyboard - product
#    segment - consumer
# 2,best - south
#   worst - north
# 3, consumer
# 4, category - electronics
#    region - south
# 5, no trend
# 6, no
# 7, there is outliers in sales
# 8, +some areas have low performance ,improve them
#    +dont give higher discounts
#    +increase sales of clothing and office supplies
